# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import seaborn as sb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#matplotlib.rcParams['text.usetex'] = True
#matplotlib.rcParams['text.latex.unicode'] = True

sb.set()

# %%
records = pd.read_csv('records.csv')

# %%
records['Block Max iterations']
# Out:
# 0    5.0
# 1    5.0
# 2    5.0
# Name: Block Max iterations, dtype: float64

# %%
records[['Timestamp', 'Nodes', 'Iterant', 'Block Steps']]
# Out:
#              Timestamp  Nodes       Iterant  Block Steps
# 0  2018-04-25 15:23:22    1.0  ablockjacobi          1.0
# 1  2018-04-25 15:24:49    8.0  ablockjacobi          1.0
# 2  2018-04-25 15:26:55   32.0  ablockjacobi          1.0

# %%
df1 = pd.read_csv('2018-04-25_15-23-22.csv', index_col=0)
df8 = pd.read_csv('2018-04-25_15-24-49.csv', index_col=0)
df32 = pd.read_csv('2018-04-25_15-26-55.csv', index_col=0)

# %%
toma = pd.concat([df1.iloc[:,0],
                  df8.iloc[:,0],
                  df32.iloc[:,0]], axis=1)
toma.columns = ['Nodes 1', 'Nodes 8', 'Nodes 32']
toma.head()
# Out:
#           Nodes 1  Nodes 8  Nodes 32
# Time [s]
# 0.000000      1.0      1.0       1.0
# 0.001010      NaN      NaN       NaN
# 0.001044      NaN      NaN       NaN
# 0.001076      NaN      NaN       NaN
# 0.001130      NaN      NaN       NaN

# %% [markdown]
# # Convergence

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, sharex=True)
toma.iloc[::1].plot(ax=ax, logy=True, ms=5, style=['.', '.', '.'])
ax.set_ylabel('Relative error')

# fig.savefig('toma.png', dpi=300)
# Out:
# Text(0,0.5,'Relative error')

# %% [markdown]
# # Iteration rate

# %%
df32.count().mean() / df1.count().mean()
# Out:
# 1.1848757172809534

# %%
toma['Nodes 1'].count()
# Out:
# 15
